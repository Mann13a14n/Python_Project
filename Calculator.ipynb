# %%
from tkinter import*
def btnClick(number):
    global val
    val=val+str(number)
    data.set(val)
    
# Function for clear the button
def btnClear():
    global val
    val=""
    data.set("")
    
# Function for Result
def btnEquals():
    result=str(eval(val))
    data.set(result)
    
def btnBack():
    global val
    val= val[:-1]
    data.set(val)
    s

root=Tk()
root.title("Calculator")
root.geometry("360x430+500+200")

val=""

data=StringVar()

display=Entry(root,textvariable=data, bd=18, justify="right",bg="#D3D3D3", font=("Arial", 22))
display.grid(row=0, columnspan=4)

btn1=Button(root,text="1",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(1))
btn1.grid(row=2, column=0)

btn2=Button(root,text="2",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(2))
btn2.grid(row=2, column=1)


btn3=Button(root,text="3",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(3))
btn3.grid(row=2, column=2)


btnAdd=Button(root,text="+",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick("+"))
btnAdd.grid(row=2, column=3)

btn4=Button(root,text="4",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(4))
btn4.grid(row=3, column=0)

btn5=Button(root,text="5",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(5))
btn5.grid(row=3, column=1)


btn6=Button(root,text="6",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(6))
btn6.grid(row=3, column=2)


btnSubstract=Button(root,text="-",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick("-"))
btnSubstract.grid(row=3, column=3)

btn7=Button(root,text="7",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(7))
btn7.grid(row=4, column=0)

btn8=Button(root,text="8",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(8))
btn8.grid(row=4, column=1)


btn9=Button(root,text="9",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(9))
btn9.grid(row=4, column=2)


btnMultiply=Button(root,text="*",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick("*"))
btnMultiply.grid(row=4, column=3)

btnClear=Button(root,text="AC",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=btnClear)
btnClear.grid(row=5, column=0)

btn0=Button(root,text="0",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(0))
btn0.grid(row=5, column=1)


btnEqual=Button(root,text="=",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=btnEquals)
btnEqual.grid(row=5, column=2)


btnDevide=Button(root,text="÷",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick("÷"))
btnDevide.grid(row=5, column=3)

btnparentheses=Button(root,text="(",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick("("))
btnparentheses.grid(row=6, column=0)

btnparentheses=Button(root,text=")",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick(")"))
btnparentheses.grid(row=6, column=1)


btnpercentage=Button(root,text="%",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=lambda:btnClick("%"))
btnpercentage.grid(row=6, column=2)


btnBack=Button(root,text="←",font=("Arial", 12, "bold"), bd=12, height=2,width=6, command=btnBack)
btnBack.grid(row=6, column=3)


mainloop()
